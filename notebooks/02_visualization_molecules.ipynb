# %%
from ase.io import read
from ase.visualize import view

# %%
hbn = read("..\\data\\h-BN.cif")
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\ase\io\cif.py:411: UserWarning: crystal system 'trigonal' is not interpreted for space group Spacegroup(164, setting=1). This may result in wrong setting!
#   warnings.warn(

# %%
view(hbn)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\Admin\\anaconda3\\python.exe', '...>

# %%
sillicon = read("..\\data\\sillicon.cif")

# %%
view(sillicon)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\Admin\\anaconda3\\python.exe', '...>

# %%
## Visualization through nglview

# %%
pip install nglview
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nglview as nv

# %%
nv.show_ase(hbn)
# Out:
# NGLWidget()

# %%
nv.show_ase(sillicon)
# Out:
# NGLWidget()

# %% [markdown]
# ##### 1. The h-BN structure exhibits layered arrangment with alternating boron and nitrogen atoms.
# ##### 2. Silicon forms a three-dimensional covalent crystal network with cubic symmetry.
# ##### 3. h-BN appears structurally less dense compared to silicon due to its layred geometry.
# ##### 4. Visulization helps reveal periodically and atomic arrangement more intuitively than numerical coordinates alone.
